# %% [markdown]
# # Alternating Series Test
# © Kelly McQuighan 2016

# %% [markdown]
# ## Introduction
#
# The purpose of this notebook is to understand the Alternating Series Test:
#
# **Theoerem (Alternating Series Test):** The alternating series $\sum_{k=1}^\infty (-1)^{k+1}a_k$ converges provided $0<a_{k+1}\le a_k$ and $\lim_{k\to\infty} a_k = 0$.
#
# **Remark** If the series is not alternating, then the above theorem is NOT true. Consider, for example $\sum_{k=1}^\infty \frac 1k$
#
# ## Set-up
#
# The notebook relies on Python code. To initialize the notebook ** Select Cell->Run All Below**

# %%
from ipywidgets import interact, Text, IntSlider
import ipywidgets as widgets
# %matplotlib inline
import AlternatingTools as AT

# %% [markdown]
# ## The proof
#
# Watch what happens to $s_n=\sum_{k=1}^n(-1)^{k+1} a_n$ as more terms are added to the alternating series.
#
# **Do:** Pick a value of n and an explicit sequence $a_n$. Change n to successively larger values to see what happens to the series $\sum_{k=1}^na_n$.
#
# **Consider:** How is the plot on the right related to the plot on the left?
#
# **Some sequences to try**
# - 1./n\*\*2
# - 1./n\*\*0.5

# %%
#DO NOT CHANGE ANYTHING IN THIS BOX
f_box = Text(value="1/n", description=r'$f(n)=$')
n_slider = widgets.IntSlider(min=1, max=20, step=1, value=1)
interact(AT.proof, f=f_box, n=n_slider);
